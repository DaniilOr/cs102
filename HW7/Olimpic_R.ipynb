# %%
df <- read.csv('athlete_events.csv')

# %%
df
# Out:
#        ID     Name                               Sex Age Height Weight
# 1       1     A Dijiang                          M   24  180    80
# 2       2     A Lamusi                           M   23  170    60
# 3       3     Gunnar Nielsen Aaby                M   24   NA    NA
# 4       4     Edgar Lindenau Aabye               M   34   NA    NA
# 5       5     Christine Jacoba Aaftink           F   21  185    82
# 6       5     Christine Jacoba Aaftink           F   21  185    82
# 7       5     Christine Jacoba Aaftink           F   25  185    82
# 8       5     Christine Jacoba Aaftink           F   25  185    82
# 9       5     Christine Jacoba Aaftink           F   27  185    82
# 10      5     Christine Jacoba Aaftink           F   27  185    82
# 11      6     Per Knut Aaland                    M   31  188    75
# 12      6     Per Knut Aaland                    M   31  188    75
# 13      6     Per Knut Aaland                    M   31  188    75
# ...

# %% [markdown]
# __1. How old were the youngest male and female participants of the 1996 Olympics?__
#
# - 16 and 15
# - **14 and 12**
# - 16 and 12
# - 13 and 11

# %%
library("magrittr")
library("sjm")

# %%
min(df[df['Sex'] == 'F'& df['Games'] == '1996 Summer', 'Age'], na.rm=T)
# Out:
# [1] 12

# %%
min(df[df['Sex'] == 'M'& df['Games'] == '1996 Summer', 'Age'], na.rm=T)
# Out:
# [1] 14

# %% [markdown]
# __2. What was the percentage of male gymnasts among all the male participants of the 2000 Olympics? Round the answer to the first decimal.__
#
# *Hint:* here and further if needed drop duplicated sportsmen to count only unique ones.
#
# - 0.2
# - **1.5**
# - 2.5
# - 7.7

# %%
needed <- df[!duplicated(df$Name),]
gymnasts <- needed[needed['Sport'] == 'Gymnastics' & needed['Games'] == '2000 Summer' & needed['Sex'] == 'M', ]
sportsmen <- needed[needed['Games'] == '2000 Summer' & needed['Sex'] == 'M',]
sportsmen
# Out:
#        ID     Name                                   Sex Age Height Weight
# 32      12    Jyri Tapani Aalto                      M   31  172     70
# 58      18    Timo Antero Aaltonen                   M   31  189    130
# 82      23    Fritz Aanes                            M   22  187     89
# 147     53    Talaat Abada                           M   24  172     58
# 166     68    Pablo Martn Abal                       M   23  178     76
# 169     70    Jess Iory Aball Martnez                M   26  167     65
# 179     76    Jouan Patrice Abanda Etong             M   22  185     82
# 185     82    Enrique Abaroa Martnez                 M   26  183     75
# 243    118    Mahmoud Abbas                          M   22  165     65
# 248    123    Sohail Abbas                           M   25  178     80
# 263    134    Christian Abbiati                      M   23  192     90
# 265    136    Alessandro Abbio                       M   29  195     85
# ...

# %%
print(nrow(gymnasts) / nrow(sportsmen) * 100)
# Out:
# [1] 1.462264

# %% [markdown]
# __3. What are the mean and standard deviation of height for female basketball players participated in the 2000 Olympics? Round the answer to the first decimal.__
#
# - 178.5 and 7.2
# - 179.4 and 10
# - 180.7 and 6.7
# - **182.4 and 9.1**

# %%
#df <- df[!duplicated(df$Name),]
needed <- df[df['Sex'] == 'F' & df['Sport'] == 'Basketball' & df['Games'] == '2000 Summer', ]

# %%
lapply(needed['Height'], mean, na.rm = TRUE)
# Out:
# $Height
# [1] 182.3873

# %%
lapply(needed['Height'], sd, na.rm = TRUE)
# Out:
# $Height
# [1] 9.139462

# %% [markdown]
# __4. Find a sportsperson participated in the 2002 Olympics, with the highest weight among other participants of the same Olympics. What sport did he or she do?__
#
# - Judo
# - **Bobsleigh**
# - Weightlifting
# - Boxing

# %%
needed = df[df['Weight'] == lapply(df[df['Games'] == '2002 Winter', ]['Weight'], max, na.rm=TRUE) & df['Games'] == '2002 Winter',]['Sport']

# %%
needed[!is.na(needed['Sport']), 'Sport']
# Out:
# [1] Bobsleigh
# 66 Levels: Aeronautics Alpine Skiing Alpinism Archery ... Wrestling

# %% [markdown]
# __5. How many times did Pawe Abratkiewicz participate in the Olympics held in different years?__
#
# - 0
# - 1
# - 2
# - ***3***

# %%
needed = df[df['Name'] == 'Pawe Abratkiewicz' ,]
nrow(needed[!duplicated(needed$Games), ])
# Out:
# [1] 3

# %% [markdown]
# __6. How many silver medals in tennis did Australia win at the 2000 Olympics?__
#
# - 0
# - 1
# - **2**
# - 3

# %%
needed <- df[df['Team'] == 'Australia' & df['Medal'] == 'Silver' & df['Games'] == '2000 Summer' & df['Sport'] == 'Tennis', ]

# %%
nrow(needed[!is.na(needed$ID),])
# Out:
# [1] 2

# %% [markdown]
# __7. Is it true that Switzerland won fewer medals than Serbia at the 2016 Olympics? Do not consider NaN values in _Medal_ column.__
#
# - **Yes**
# - No

# %%
sw <- df[df['Team'] == 'Switzerland' & !is.na(df['Medal']) & df['Games'] == '2016 Summer', ]
sb <- df[df['Team'] == 'Serbia' & !is.na(df['Medal']) & df['Games'] == '2016 Summer', ]

# %%
nrow(sw) < nrow(sb)
# Out:
# [1] TRUE

# %% [markdown]
# __8. What age category did the fewest and the most participants of the 2014 Olympics belong to?__
# - [45-55] and [25-35) correspondingly
# - **[45-55] and [15-25) correspondingly**
# - [35-45] and [25-35) correspondingly
# - [45-55] and [35-45) correspondingly

# %%
elder = df[(55 >= df['Age']) & (df['Age'] >= 45), ]
adults = df[(45 >= df['Age']) & (df['Age'] >= 35), ]
print(nrow(elder) < nrow(adults))
young = df[(25 > df['Age']) & (df['Age'] >= 15), ]
adults = df[(45 > df['Age']) & (df['Age'] >= 35),]
medium = df[(35 > df['Age']) & (df['Age'] >= 25),]
print((nrow(young) > nrow(medium)) && (nrow(young) > nrow(adults)))
# Out:
# [1] TRUE
# [1] TRUE

# %% [markdown]
# __9. Is it true that there were Summer Olympics held in Lake Placid? Is it true that there were Winter Olympics held in Sankt Moritz?__
#
# - Yes, Yes
# - Yes, No
# - **No, Yes**
# - No, No

# %%
print(nrow(df[(df['City'] == 'Lake Placid') & (df$Season == 'Summer'),]) > 0)
print(nrow(df[(df['City'] == 'Sankt Moritz') & (df$Season == 'Winter'),]) > 0)
# Out:
# [1] FALSE
# [1] TRUE

# %% [markdown]
# __10. What is the absolute difference between the number of unique sports at the 1995 Olympics and 2016 Olympics?__
#
# - 16
# - 24
# - 26
# - **34**

# %%
#df = df[!duplicated(df['Sport']),]
s1995 = df[df['Year'] == 1995, ]

s2016 =  df[df['Year']== 2016, ]

print(nrow(s1995[!duplicated(s1995['Sport']),]) - nrow(s2016[!duplicated(s2016['Sport']),]))
# Out:
# [1] -34
